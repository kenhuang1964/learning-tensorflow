# %% [markdown]
# <a href="https://colab.research.google.com/github/kenhuangsy/learning-tensorflow/blob/main/01_Exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import libraries

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="darkgrid")

# %% [markdown]
# Import dataset

# %%
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.boston_housing.load_data(
    path="boston_housing.npz", test_split=0.2, seed=42
)
# Out:
# ...
# 65536/57026 [==================================] - 0s 0us/step

# %%
X_train
# Out:
# array([[9.1780e-02, 0.0000e+00, 4.0500e+00, ..., 1.6600e+01, 3.9550e+02,
#         9.0400e+00],
#        [5.6440e-02, 4.0000e+01, 6.4100e+00, ..., 1.7600e+01, 3.9690e+02,
#         3.5300e+00],
#        [1.0574e-01, 0.0000e+00, 2.7740e+01, ..., 2.0100e+01, 3.9011e+02,
#         1.8070e+01],
#        ...,
#        [3.0410e-02, 0.0000e+00, 5.1900e+00, ..., 2.0200e+01, 3.9481e+02,
#         1.0560e+01],
#        [5.2058e-01, 0.0000e+00, 6.2000e+00, ..., 1.7400e+01, 3.8845e+02,
#         9.5400e+00],
#        [2.5199e-01, 0.0000e+00, 1.0590e+01, ..., 1.8600e+01, 3.8943e+02,
#         1.8060e+01]])

# %% [markdown]
# Creating our model

# %%
tf.random.set_seed(42)

# 1. Build our model
model_1 = tf.keras.Sequential([
    tf.keras.layers.Dense(100, activation = "relu"),
    tf.keras.layers.Dense(100, activation = "relu"),
    tf.keras.layers.Dense(100, activation = "relu"),
    tf.keras.layers.Dense(100, activation = "relu"),
    tf.keras.layers.Dense(1)
])

# 2. Compile our model
model_1.compile(loss = tf.keras.losses.mae,
                optimizer = tf.keras.optimizers.Adam(learning_rate=0.01),
                metrics = ["mae"])

# 3. Fit our model
model_1.fit(X_train, y_train, epochs = 500)
# Out:
# Epoch 1/500
# 13/13 [==============================] - 1s 3ms/step - loss: 20.8849 - mae: 20.8849
# Epoch 2/500
# 13/13 [==============================] - 0s 3ms/step - loss: 7.1716 - mae: 7.1716
# Epoch 3/500
# 13/13 [==============================] - 0s 3ms/step - loss: 5.5348 - mae: 5.5348
# Epoch 4/500
# 13/13 [==============================] - 0s 3ms/step - loss: 5.2253 - mae: 5.2253
# Epoch 5/500
# 13/13 [==============================] - 0s 3ms/step - loss: 5.1774 - mae: 5.1774
# Epoch 6/500
# 13/13 [==============================] - 0s 3ms/step - loss: 5.3359 - mae: 5.3359
# Epoch 7/500
# 13/13 [==============================] - 0s 3ms/step - loss: 5.3228 - mae: 5.3228
# Epoch 8/500
# 13/13 [==============================] - 0s 4ms/step - loss: 5.1432 - mae: 5.1432
# Epoch 9/500
# 13/13 [==============================] - 0s 4ms/step - loss: 5.6299 - mae: 5.6299
# Epoch 10/500
# 13/13 [==============================] - 0s 3ms/step - loss: 5.1817 - mae: 5.1817
# Epoch 11/500
# ...

# %%
model_1.evaluate(X_test, y_test)
# Out:
# 4/4 [==============================] - 0s 3ms/step - loss: 2.4496 - mae: 2.4496
# [2.449575424194336, 2.449575424194336]

# %%
tf.random.set_seed(42)

# 1. Build our model
model_2 = tf.keras.Sequential([
    tf.keras.layers.Dense(50, activation = "relu"),
    tf.keras.layers.Dense(50, activation = "relu"),
    tf.keras.layers.Dense(50, activation = "relu"),
    tf.keras.layers.Dense(50, activation = "relu"),
    tf.keras.layers.Dense(1)
])

# 2. Compile our model
model_2.compile(loss = tf.keras.losses.mae,
                optimizer = tf.keras.optimizers.Adam(learning_rate=0.01),
                metrics = ["mae"])

# 3. Fit our model
model_2.fit(X_train, y_train, epochs = 500)
# Out:
# Epoch 1/500
# 13/13 [==============================] - 1s 3ms/step - loss: 13.0526 - mae: 13.0526
# Epoch 2/500
# 13/13 [==============================] - 0s 3ms/step - loss: 5.7463 - mae: 5.7463
# Epoch 3/500
# 13/13 [==============================] - 0s 2ms/step - loss: 5.5045 - mae: 5.5045
# Epoch 4/500
# 13/13 [==============================] - 0s 3ms/step - loss: 5.6365 - mae: 5.6365
# Epoch 5/500
# 13/13 [==============================] - 0s 3ms/step - loss: 5.4013 - mae: 5.4013
# Epoch 6/500
# 13/13 [==============================] - 0s 2ms/step - loss: 5.2531 - mae: 5.2531
# Epoch 7/500
# 13/13 [==============================] - 0s 3ms/step - loss: 4.9486 - mae: 4.9486
# Epoch 8/500
# 13/13 [==============================] - 0s 3ms/step - loss: 5.3559 - mae: 5.3559
# Epoch 9/500
# 13/13 [==============================] - 0s 3ms/step - loss: 5.8590 - mae: 5.8590
# Epoch 10/500
# 13/13 [==============================] - 0s 2ms/step - loss: 5.0110 - mae: 5.0110
# Epoch 11/500
# ...

# %%
model_2.evaluate(X_test, y_test)
# Out:
# 4/4 [==============================] - 0s 3ms/step - loss: 2.6501 - mae: 2.6501
# [2.6501312255859375, 2.6501312255859375]
